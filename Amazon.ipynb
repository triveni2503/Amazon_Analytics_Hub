# %%
import pandas as pd

# %%
df = pd.read_csv("../DataSets/Amazon_Dataset.csv")

# %%
df
# Out:
#            Name   BirthDate MaritalStatus Gender  \
# 0         Wyatt  1983-04-28             M      M
# 1       Shannon  1948-06-26             S      F
# 2      Clarence  1948-10-09             S      M
# 3          Luke  1982-03-07             S      M
# 4        Jordan  1982-09-20             S      M
# ...         ...         ...           ...    ...
# 18463     Tommy  1962-07-04             M      M
# 18464      Nina  1964-11-10             S      F
# 18465      Ivan  1964-01-05             S      M
# 18466   Clayton  1963-03-05             M      M
# 18467     Jésus  1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.dtypes
# Out:
# Name               object
# BirthDate          object
# MaritalStatus      object
# Gender             object
# EmailAddress       object
# YearlyIncome        int64
# Region             object
# City               object
# State-Province     object
# CategoryName       object
# ItemCost          float64
# NumberofItem        int64
# dtype: object

# %%
df.describe()
# Out:
#         YearlyIncome      ItemCost  NumberofItem
# count   18468.000000  18468.000000  18468.000000
# mean    57293.155729    898.636953     50.155891
# std     32292.579356   1233.956478     28.885948
# min     10000.000000      2.290000      1.000000
# 25%     30000.000000      8.990000     25.000000
# 50%     60000.000000     35.000000     50.000000
# 75%     70000.000000   2071.419600     75.000000
# max    170000.000000   3578.270000    100.000000

# %%
col = df[['Name','BirthDate','EmailAddress']]

# %%
col
# Out:
#            Name   BirthDate                    EmailAddress
# 0         Wyatt  1983-04-28     wyatt32@adventure-works.com
# 1       Shannon  1948-06-26    shannon1@adventure-works.com
# 2      Clarence  1948-10-09  clarence32@adventure-works.com
# 3          Luke  1982-03-07      luke18@adventure-works.com
# 4        Jordan  1982-09-20    jordan73@adventure-works.com
# ...         ...         ...                             ...
# 18463     Tommy  1962-07-04      tommy2@adventure-works.com
# 18464      Nina  1964-11-10      nina21@adventure-works.com
# 18465      Ivan  1964-01-05       ivan0@adventure-works.com
# 18466   Clayton  1963-03-05    clayton0@adventure-works.com
# 18467     Jésus  1963-12-08      jésus9@adventure-works.com
#
# [18468 rows x 3 columns]

# %%
df[-20:]
# Out:
#              Name   BirthDate MaritalStatus Gender  \
# 18448      Eugene  1981-09-05             S      M
# 18449         Roy  1981-06-19             S      M
# 18450       Lance  1947-11-26             M      M
# 18451      Monica  1965-10-16             M      F
# 18452  Jacqueline  1965-06-27             M      F
# 18453   Dominique  1965-04-26             M      F
# 18454      Nathan  1964-08-25             S      M
# 18455        Dana  1964-03-26             S      F
# 18456       Lacey  1964-03-14             M      F
# 18457      Carmen  1964-05-22             S      F
# 18458       Jaime  1963-10-04             M      M
# 18459       Jared  1963-09-23             S      M
# 18460   Elizabeth  1963-07-03             M      F
# 18461        Neil  1963-07-06             M      M
# 18462      Darren  1963-05-25             S      M
# 18463       Tommy  1962-07-04             M      M
# 18464        Nina  1964-11-10             S      F
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# BirthDate             0
# MaritalStatus         0
# Gender                1
# EmailAddress          1
# YearlyIncome          0
# Region                0
# City                  0
# State-Province        0
# CategoryName      18071
# ItemCost              0
# NumberofItem          0
# dtype: int64

# %%
df.Gender = df.Gender.fillna('unknow')
df.EmailAddress = df.EmailAddress.fillna('unknow')
df
# Out:
#            Name   BirthDate MaritalStatus Gender  \
# 0         Wyatt  1983-04-28             M      M
# 1       Shannon  1948-06-26             S      F
# 2      Clarence  1948-10-09             S      M
# 3          Luke  1982-03-07             S      M
# 4        Jordan  1982-09-20             S      M
# ...         ...         ...           ...    ...
# 18463     Tommy  1962-07-04             M      M
# 18464      Nina  1964-11-10             S      F
# 18465      Ivan  1964-01-05             S      M
# 18466   Clayton  1963-03-05             M      M
# 18467     Jésus  1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# BirthDate             0
# MaritalStatus         0
# Gender                0
# EmailAddress          0
# YearlyIncome          0
# Region                0
# City                  0
# State-Province        0
# CategoryName      18071
# ItemCost              0
# NumberofItem          0
# dtype: int64

# %%
df = df.drop(['CategoryName'],axis=1)

# %%
df
# Out:
#            Name   BirthDate MaritalStatus Gender  \
# 0         Wyatt  1983-04-28             M      M
# 1       Shannon  1948-06-26             S      F
# 2      Clarence  1948-10-09             S      M
# 3          Luke  1982-03-07             S      M
# 4        Jordan  1982-09-20             S      M
# ...         ...         ...           ...    ...
# 18463     Tommy  1962-07-04             M      M
# 18464      Nina  1964-11-10             S      F
# 18465      Ivan  1964-01-05             S      M
# 18466   Clayton  1963-03-05             M      M
# 18467     Jésus  1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.BirthDate = df.BirthDate.astype('datetime64[ns]')

# %%
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28             M      M
# 1       Shannon 1948-06-26             S      F
# 2      Clarence 1948-10-09             S      M
# 3          Luke 1982-03-07             S      M
# 4        Jordan 1982-09-20             S      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04             M      M
# 18464      Nina 1964-11-10             S      F
# 18465      Ivan 1964-01-05             S      M
# 18466   Clayton 1963-03-05             M      M
# 18467     Jésus 1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.Region.unique()
# Out:
# array(['South', 'East', 'Central', 'West', 'North'], dtype=object)

# %%
df.City.nunique()
# Out:
# 269

# %%
df['State-Province'].unique()
# Out:
# array(['California', 'Victoria', 'British Columbia', 'Oregon',
#        'Washington', 'Queensland', 'New South Wales', 'South Australia',
#        'Tasmania', 'Nordrhein-Westfalen', 'England', 'Essonne', 'Yveline',
#        'Hessen', 'Hamburg', 'Seine Saint Denis', 'Saarland', 'Bayern',
#        'Seine (Paris)', 'Pas de Calais', 'Moselle', 'Hauts de Seine',
#        'Nord', 'Seine et Marne', 'Loir et Cher', 'Loiret',
#        'Charente-Maritime', 'Brandenburg', 'Alabama', "Val d'Oise",
#        'Val de Marne', 'Minnesota', 'Wyoming', 'Ohio', 'Garonne (Haute)',
#        'Kentucky', 'New York', 'Texas', 'Missouri', 'Somme', 'Alberta',
#        'Georgia', 'Florida', 'Illinois', 'South Carolina',
#        'North Carolina', 'Virginia', 'Ontario', 'Mississippi', 'Montana',
#        'Arizona', 'Massachusetts', 'Utah'], dtype=object)

# %%
df.Region.value_counts()
# Out:
# Region
# East       6921
# South      6920
# West       4616
# North         9
# Central       2
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.replace("-",'')

# %%
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28             M      M
# 1       Shannon 1948-06-26             S      F
# 2      Clarence 1948-10-09             S      M
# 3          Luke 1982-03-07             S      M
# 4        Jordan 1982-09-20             S      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04             M      M
# 18464      Nina 1964-11-10             S      F
# 18465      Ivan 1964-01-05             S      M
# 18466   Clayton 1963-03-05             M      M
# 18467     Jésus 1963-12-08             M      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
df.MaritalStatus = df.MaritalStatus.replace(['M','S'],['Married','Single'],regex=True)

# %%
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28       Married      M
# 1       Shannon 1948-06-26        Single      F
# 2      Clarence 1948-10-09        Single      M
# 3          Luke 1982-03-07        Single      M
# 4        Jordan 1982-09-20        Single      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04       Married      M
# 18464      Nina 1964-11-10        Single      F
# 18465      Ivan 1964-01-05        Single      M
# 18466   Clayton 1963-03-05       Married      M
# 18467     Jésus 1963-12-08       Married      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
cal = df[df.StateProvince == 'California']
cal
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28       Married      M
# 7          Seth 1982-10-11       Married      M
# 8       Russell 1982-09-17       Married      M
# 20     Jennifer 1982-12-18       Married      F
# 25       Amanda 1981-10-16       Married      F
# ...         ...        ...           ...    ...
# 18310  Victoria 1984-02-17        Single      F
# 18312     Jason 1983-10-13       Married      M
# 18331  Jonathan 1969-08-15       Married      M
# 18334     Julia 1969-11-09        Single      F
# 18336     Lydia 1969-08-11        Single      F
#
#                          EmailAddress  YearlyIncome   Region            City  \
# 0         wyatt32@adventure-works.com         30000    South  Imperial Beach
# 7          seth46@adventure-works.com         40000     West      Bellflower
# 8        russell7@adventure-works.com         60000  Central         Concord
# ...

# %%
cal = df[df.StateProvince == 'Ohio']
cal
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 716       Erick 1963-02-08       Married      M
# 1940   Marshall 1966-03-11        Single      M
# 10233     Alvin 1981-03-18        Single      M
# 16024      Paul 1961-06-06       Married      M
#
#                          EmailAddress  YearlyIncome Region        City  \
# 716       erick20@adventure-works.com         60000   East  Cincinnati
# 1940   marshall12@adventure-works.com         70000   East  Cincinnati
# 10233     alvin27@adventure-works.com         40000   East    Columbus
# 16024       paul5@adventure-works.com         20000  South     Burbank
#
#       StateProvince  ItemCost  NumberofItem
# 716            Ohio   3578.27            72
# 1940           Ohio   3578.27             1
# 10233          Ohio     54.99            94
# 16024          Ohio     35.00            94

# %%
cal = df[df.StateProvince == 'Utah']
cal
# Out:
#           Name  BirthDate MaritalStatus Gender                  EmailAddress  \
# 17790  Randall 1977-11-19        Single      M  randall5@adventure-works.com
# 17843    Micah 1970-10-09        Single      M    micah9@adventure-works.com
#
#        YearlyIncome Region        City StateProvince  ItemCost  NumberofItem
# 17790         40000  South  Cedar City          Utah      2.29            23
# 17843         80000   West   Bountiful          Utah      4.99            23

# %%
df[(df.Region == 'Central') & (df.YearlyIncome >= 50000)]
# Out:
#       Name  BirthDate MaritalStatus Gender                  EmailAddress  \
# 8  Russell 1982-09-17       Married      M  russell7@adventure-works.com
#
#    YearlyIncome   Region     City StateProvince  ItemCost  NumberofItem
# 8         60000  Central  Concord    California   3399.99            45

# %%
df.dtypes
# Out:
# Name                     object
# BirthDate        datetime64[ns]
# MaritalStatus            object
# Gender                   object
# EmailAddress             object
# YearlyIncome              int64
# Region                   object
# City                     object
# StateProvince            object
# ItemCost                float64
# NumberofItem              int64
# dtype: object

# %%
df['Sales'] = df['ItemCost'] * df['NumberofItem']
df
# Out:
#            Name  BirthDate MaritalStatus Gender  \
# 0         Wyatt 1983-04-28       Married      M
# 1       Shannon 1948-06-26        Single      F
# 2      Clarence 1948-10-09        Single      M
# 3          Luke 1982-03-07        Single      M
# 4        Jordan 1982-09-20        Single      M
# ...         ...        ...           ...    ...
# 18463     Tommy 1962-07-04       Married      M
# 18464      Nina 1964-11-10        Single      F
# 18465      Ivan 1964-01-05        Single      M
# 18466   Clayton 1963-03-05       Married      M
# 18467     Jésus 1963-12-08       Married      M
#
#                          EmailAddress  YearlyIncome   Region  \
# 0         wyatt32@adventure-works.com         30000    South
# 1        shannon1@adventure-works.com         20000     East
# 2      clarence32@adventure-works.com         30000  Central
# 3          luke18@adventure-works.com         40000     West
# 4        jordan73@adventure-works.com         40000     East
# ...

# %%
a = df.groupby('StateProvince')['YearlyIncome'].mean().reset_index()
pd.DataFrame(a)
# Out:
#           StateProvince   YearlyIncome
# 0               Alabama   40000.000000
# 1               Alberta   51818.181818
# 2               Arizona   40000.000000
# 3                Bayern   40789.473684
# 4           Brandenburg   38000.000000
# 5      British Columbia   57216.164208
# 6            California   66592.392528
# 7     Charente-Maritime   47142.857143
# 8               England   52169.367486
# 9               Essonne   33600.000000
# 10              Florida   56666.666667
# 11      Garonne (Haute)   29000.000000
# 12              Georgia   66666.666667
# 13              Hamburg   43367.003367
# 14       Hauts de Seine   36871.794872
# 15               Hessen   42148.541114
# 16             Illinois   45000.000000
# 17             Kentucky   70000.000000
# 18         Loir et Cher   42352.941176
# 19               Loiret   29000.000000
# 20        Massachusetts   60000.000000
# 21            Minnesota   80000.000000
# 22          Mississippi   40000.000000
# ...

# %%
a = df.groupby('StateProvince')['Gender'].value_counts()
pd.DataFrame(a)
# Out:
#                       count
# StateProvince Gender
# Alabama       F           1
# Alberta       M           6
#               F           5
# Arizona       M           1
#               F           1
# ...                     ...
# Washington    F        1115
# Wyoming       M           1
#               F           1
# Yveline       M          89
#               F          79
#
# [94 rows x 1 columns]

# %%
a = pd.pivot_table(df,values='Name',index='StateProvince',columns='Gender',aggfunc='count',fill_value=0).reset_index()
a
# Out:
# Gender        StateProvince     F     M  unknow
# 0                   Alabama     1     0       0
# 1                   Alberta     5     6       0
# 2                   Arizona     1     1       0
# 3                    Bayern   114   114       0
# 4               Brandenburg    14    16       0
# 5          British Columbia   761   798       0
# 6                California  2205  2238       0
# 7         Charente-Maritime     7    14       0
# 8                   England   934   979       0
# 9                   Essonne    83    67       0
# 10                  Florida     2     1       0
# 11          Garonne (Haute)    16    14       0
# 12                  Georgia     2     1       0
# 13                  Hamburg   146   151       0
# 14           Hauts de Seine    93   102       0
# 15                   Hessen   191   186       0
# 16                 Illinois     2     4       0
# 17                 Kentucky     0     1       0
# 18             Loir et Cher     8     9       0
# ...

# %%
a = df.groupby('Region')['MaritalStatus'].value_counts()
pd.DataFrame(a)
# Out:
#                        count
# Region  MaritalStatus
# Central Married            1
#         Single             1
# East    Married         3743
#         Single          3178
# North   Single             8
#         Married            1
# South   Married         3777
#         Single          3143
# West    Married         2483
#         Single          2133

# %%
a = pd.pivot_table(df,values='Name',index='Region',columns='MaritalStatus',aggfunc='count',fill_value=0).reset_index()
a
# Out:
# MaritalStatus   Region  Married  Single
# 0              Central        1       1
# 1                 East     3743    3178
# 2                North        1       8
# 3                South     3777    3143
# 4                 West     2483    2133

# %%
a = pd.pivot_table(df,values='NumberofItem',index='Region',columns='Gender',aggfunc='min',fill_value=0).reset_index()
a
# Out:
# Gender   Region  F   M  unknow
# 0       Central  0  45       0
# 1          East  1   1      92
# 2         North  5  19       0
# 3         South  1   1       0
# 4          West  1   1       0

# %%
a = pd.pivot_table(df,values='Sales',index='Gender',columns='MaritalStatus',aggfunc='sum',fill_value=0).reset_index()
a
# Out:
# MaritalStatus  Gender       Married        Single
# 0                   F  2.177250e+08  2.036068e+08
# 1                   M  2.464850e+08  1.724245e+08
# 2              unknow  3.292008e+05  0.000000e+00
